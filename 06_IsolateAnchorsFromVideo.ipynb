# %%
import numpy as np
import pandas as pd

import cv2
import os

# %%
base_dir = '/Users/vivekhsridhar/Library/Mobile Documents/com~apple~CloudDocs/Documents/Code/Python/SpatialRegistration/io/'

# %%
df = pd.read_csv(base_dir + 'anchoredp1d1.csv')
df['best_anchor_frame'] = df['best_anchor_frame'].astype(int)
df.head()
# Out:
#    frame         x        y  idx  best_anchor_frame  transformed_x  \
# 0      0  3231.399   58.680    1                  0       3231.399
# 1      0  1596.498  174.696    2                  0       1596.498
# 2      0  3602.919  276.867    3                  0       3602.919
# 3      0  2578.536  318.834    4                  0       2578.536
# 4      0  1220.571  437.763    5                  0       1220.571
#
#    transformed_y
# 0         58.680
# 1        174.696
# 2        276.867
# 3        318.834
# 4        437.763

# %%
# Step 1: Extract unique frame numbers from the 'anchor_frames' column
unique_frames = df['best_anchor_frame'].unique()

# Define the video path
video_path = base_dir + '20230310_SE_Lek1_P1D1_DJI_0190.MP4'  # Specify the correct video path
video_name = os.path.splitext(os.path.basename(video_path))[0]  # Extract video name without extension

# Step 2: Create a directory with the video name to store extracted frames
output_folder = base_dir + f'{video_name}_frames'
os.makedirs(output_folder, exist_ok=True)

# Step 3: Use OpenCV to open the video and extract frames
cap = cv2.VideoCapture(video_path)

# Get the total number of frames in the video
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Check if the video opened successfully
if not cap.isOpened():
    print("Error: Could not open the video.")
else:
    print(f"Total frames in video: {total_frames}")
    
    # Step 4: Iterate through unique frames, read and save them
    for frame_no in unique_frames:
        # Ensure frame number is within the video frame range
        if frame_no >= 0 and frame_no < total_frames:
            # Set the video frame to the specific frame number
            cap.set(cv2.CAP_PROP_POS_FRAMES, frame_no)
            
            # Read the frame
            ret, frame = cap.read()
            
            if ret:
                # Create the filename for the frame
                frame_filename = os.path.join(output_folder, f"{video_name}_frame{frame_no}.jpg")
                
                # Save the frame as an image
                cv2.imwrite(frame_filename, frame)
                print(f"Saved frame {frame_no}")
            else:
                print(f"Error: Could not read frame {frame_no}")
        else:
            print(f"Frame number {frame_no} is out of bounds")

# Release the video capture object
cap.release()
# Out:
# Total frames in video: 5805
# Saved frame 0
# Saved frame 546
# Saved frame 600
# Saved frame 609
# Saved frame 617
# Saved frame 626
# Saved frame 637
# Saved frame 645
# Saved frame 652
# Saved frame 672
# Saved frame 664
# Saved frame 678
# Saved frame 687
# Saved frame 725
# Saved frame 696
# Saved frame 703
# Saved frame 715
# Saved frame 738
# Saved frame 768
# Saved frame 822
# Saved frame 838
# Saved frame 880
# Saved frame 915
# Saved frame 924
# Saved frame 906
# Saved frame 953
# Saved frame 1108
# Saved frame 1145
# Saved frame 1163
# Saved frame 1165
# Saved frame 1167
# Saved frame 1169
# Saved frame 1316
# Saved frame 1174
# Saved frame 1243
# Saved frame 1267
# Saved frame 1358
# Saved frame 1374
# Saved frame 1676
# Saved frame 1378
# Saved frame 1810
# Saved frame 1405
# Saved frame 1727
# Saved frame 1436
# Saved frame 1496
# Saved frame 1561
# Saved frame 5463
# Saved frame 1694
# Saved frame 1850
# Saved frame 3933
# Saved frame 3091
# Saved frame 2191
# Saved frame 3478
